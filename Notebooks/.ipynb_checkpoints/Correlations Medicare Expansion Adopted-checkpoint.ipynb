# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pingouin as pg
import seaborn as sns
plt.style.use('ggplot')

# %%
overall_data = pd.read_excel('~/github/gal/Analyzing-Medicare-Expansion/Data/HEALTH DATA Adopted.xlsx')

# %%
overall_data.describe()
# Out:
#        Heart Disease Death Rate per 100,000  Cancer Death Rate per 100,000  \
# count                             31.000000                      31.000000
# mean                             160.216129                     149.696774
# std                               27.272063                      14.325862
# min                              119.000000                     123.500000
# 25%                              138.050000                     141.000000
# 50%                              159.100000                     146.500000
# 75%                              178.400000                     158.000000
# max                              217.400000                     181.600000
#
#        Poor Health  Poor Mental Health  Trouble Paying Off Medical Bills  \
# count    31.000000           31.000000                         31.000000
# mean      0.175871            0.230574                          0.271387
# std       0.034359            0.024872                          0.061048
# min       0.134000            0.189000                          0.149000
# 25%       0.146000            0.214850                          0.237500
# 50%       0.170000            0.224400                          0.265000
# 75%       0.192500            0.249300                          0.321500
# max       0.263000            0.290900                          0.390000
#
#        2018__Uninsured
# count        31.000000
# mean          0.066968
# std           0.021851
# min           0.027210
# 25%           0.053172
# 50%           0.064757
# 75%           0.078205
# max           0.120369

# %% [markdown]
# p-val is the p-value of the test. (p <.05 - columns are correlated) The general rule is that you can reject the hypothesis that the two variables are not correlated if the p-value is below 0.05.

# %%
pg.pairwise_corr(overall_data).sort_values(by=['p-unc'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#                                        X                                 Y  \
# 0   Heart Disease Death Rate per 100,000     Cancer Death Rate per 100,000
# 9                            Poor Health                Poor Mental Health
# 7          Cancer Death Rate per 100,000  Trouble Paying Off Medical Bills
# 6          Cancer Death Rate per 100,000                Poor Mental Health
# 1   Heart Disease Death Rate per 100,000                       Poor Health
# 12                    Poor Mental Health  Trouble Paying Off Medical Bills
# 3   Heart Disease Death Rate per 100,000  Trouble Paying Off Medical Bills
# 5          Cancer Death Rate per 100,000                       Poor Health
# 2   Heart Disease Death Rate per 100,000                Poor Mental Health
# 10                           Poor Health  Trouble Paying Off Medical Bills
# 11                           Poor Health                   2018__Uninsured
# 14      Trouble Paying Off Medical Bills                   2018__Uninsured
# 13                    Poor Mental Health                   2018__Uninsured
# 4   Heart Disease Death Rate per 100,000                   2018__Uninsured
# 8          Cancer Death Rate per 100,000                   2018__Uninsured
#
#      n         r         p-unc
# 0   31  0.785102  1.699069e-07
# 9   31  0.774742  3.127910e-07
# 7   31  0.754001  9.693993e-07
# 6   31  0.720563  4.847309e-06
# 1   31  0.715539  6.053345e-06
# 12  31  0.656561  6.041041e-05
# 3   31  0.634857  1.249315e-04
# 5   31  0.620829  1.941714e-04
# 2   31  0.614495  2.353446e-04
# 10  31  0.512053  3.232340e-03
# 11  31  0.322068  7.723975e-02
# 14  31  0.281425  1.251026e-01
# 13  31  0.129063  4.889591e-01
# 4   31  0.110087  5.554939e-01
# 8   31 -0.089602  6.316926e-01

# %%
overall_data.corr().round(2)
# Out:
#                                       Heart Disease Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                                  1.00
# Cancer Death Rate per 100,000                                         0.79
# Poor Health                                                           0.72
# Poor Mental Health                                                    0.61
# Trouble Paying Off Medical Bills                                      0.63
# 2018__Uninsured                                                       0.11
#
#                                       Cancer Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                           0.79
# Cancer Death Rate per 100,000                                  1.00
# Poor Health                                                    0.62
# Poor Mental Health                                             0.72
# Trouble Paying Off Medical Bills                               0.75
# 2018__Uninsured                                               -0.09
#
#                                       Poor Health  Poor Mental Health  \
# Heart Disease Death Rate per 100,000         0.72                0.61
# Cancer Death Rate per 100,000                0.62                0.72
# Poor Health                                  1.00                0.77
# Poor Mental Health                           0.77                1.00
# Trouble Paying Off Medical Bills             0.51                0.66
# 2018__Uninsured                              0.32                0.13
#
#                                       Trouble Paying Off Medical Bills  \
# Heart Disease Death Rate per 100,000                              0.63
# Cancer Death Rate per 100,000                                     0.75
# Poor Health                                                       0.51
# Poor Mental Health                                                0.66
# Trouble Paying Off Medical Bills                                  1.00
# 2018__Uninsured                                                   0.28
#
#                                       2018__Uninsured
# Heart Disease Death Rate per 100,000             0.11
# Cancer Death Rate per 100,000                   -0.09
# Poor Health                                      0.32
# Poor Mental Health                               0.13
# Trouble Paying Off Medical Bills                 0.28
# 2018__Uninsured                                  1.00

# %%
corrs = overall_data.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', square=True)
plt.title('Correlation Heatmap For States with Expand Medicare')
# Out:
# Text(0.5, 1, 'Correlation Heatmap For States with Expand Medicare')

# %%
sm = pd.plotting.scatter_matrix(overall_data, figsize=(15, 15))
plt.xlabel('xlabel', fontsize=6)
plt.ylabel('ylabel', fontsize=6)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 6)
plt.tick_params(labelsize=6)
[s.xaxis.label.set_rotation(45) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(45) for s in sm.reshape(-1)]

plt.show()
