# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pingouin as pg
import seaborn as sns
plt.style.use('ggplot')

# %%
overall_data = pd.read_excel('Desktop/All States Correlation Data.xlsx')

# %%
overall_data.describe()
# Out:
#        Heart Disease Death Rate per 100,000  Cancer Death Rate per 100,000  \
# count                             50.000000                      50.000000
# mean                             164.296000                     151.514000
# std                               27.927566                      14.349216
# min                              119.000000                     120.000000
# 25%                              145.875000                     141.975000
# 50%                              158.900000                     150.550000
# 75%                              179.550000                     160.675000
# max                              228.500000                     181.600000
#
#        Poor Health  Poor Mental Health  Trouble Paying Off Medical Bills  \
# count    50.000000           50.000000                         50.000000
# mean      0.179340            0.229724                          0.299040
# std       0.032466            0.023526                          0.065401
# min       0.134000            0.185900                          0.149000
# 25%       0.156000            0.214200                          0.263250
# 50%       0.173500            0.225100                          0.295500
# 75%       0.193750            0.245450                          0.341750
# max       0.263000            0.290900                          0.436000
#
#        Out of Pocket Cost  2018__Uninsured
# count           50.000000        50.000000
# mean          2109.820000         0.081703
# std            710.542239         0.030327
# min            800.000000         0.027210
# 25%           1510.000000         0.056302
# 50%           2220.000000         0.078932
# 75%           2600.000000         0.101761
# max           3580.000000         0.176901

# %% [markdown]
# p-val is the p-value of the test. (p <.05 - columns are correlated) The general rule is that you can reject the hypothesis that the two variables are not correlated if the p-value is below 0.05.

# %%
pg.pairwise_corr(overall_data).sort_values(by=['p-unc'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#                                        X                                 Y  \
# 0   Heart Disease Death Rate per 100,000     Cancer Death Rate per 100,000
# 1   Heart Disease Death Rate per 100,000                       Poor Health
# 11                           Poor Health                Poor Mental Health
# 13                           Poor Health                Out of Pocket Cost
# 6          Cancer Death Rate per 100,000                       Poor Health
# 7          Cancer Death Rate per 100,000                Poor Mental Health
# 8          Cancer Death Rate per 100,000  Trouble Paying Off Medical Bills
# 2   Heart Disease Death Rate per 100,000                Poor Mental Health
# 3   Heart Disease Death Rate per 100,000  Trouble Paying Off Medical Bills
# 19      Trouble Paying Off Medical Bills                   2018__Uninsured
# 12                           Poor Health  Trouble Paying Off Medical Bills
# 15                    Poor Mental Health  Trouble Paying Off Medical Bills
# 4   Heart Disease Death Rate per 100,000                Out of Pocket Cost
# 14                           Poor Health                   2018__Uninsured
# 20                    Out of Pocket Cost                   2018__Uninsured
# 16                    Poor Mental Health                Out of Pocket Cost
# 5   Heart Disease Death Rate per 100,000                   2018__Uninsured
# 9          Cancer Death Rate per 100,000                Out of Pocket Cost
# 10         Cancer Death Rate per 100,000                   2018__Uninsured
# 18      Trouble Paying Off Medical Bills                Out of Pocket Cost
# 17                    Poor Mental Health                   2018__Uninsured
#
#      n         r         p-unc
# 0   50  0.795987  4.878770e-12
# 1   50  0.746280  4.951457e-10
# 11  50  0.691548  2.688671e-08
# 13  50 -0.682155  4.893857e-08
# 6   50  0.666475  1.268337e-07
# 7   50  0.634891  7.348093e-07
# 8   50  0.599032  4.309674e-06
# 2   50  0.589381  6.692823e-06
# 3   50  0.548881  3.670400e-05
# 19  50  0.502979  1.970690e-04
# 12  50  0.421958  2.272092e-03
# 15  50  0.420613  2.354743e-03
# 4   50 -0.381493  6.265454e-03
# 14  50  0.367915  8.572283e-03
# 20  50 -0.355494  1.129297e-02
# 16  50 -0.305111  3.119617e-02
# 5   50  0.272044  5.597840e-02
# 9   50 -0.188212  1.905576e-01
# 10  50  0.081860  5.719738e-01
# 18  50  0.009945  9.453494e-01
# 17  50  0.008871  9.512434e-01

# %%
overall_data.corr().round(2)
# Out:
#                                       Heart Disease Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                                  1.00
# Cancer Death Rate per 100,000                                         0.80
# Poor Health                                                           0.75
# Poor Mental Health                                                    0.59
# Trouble Paying Off Medical Bills                                      0.55
# Out of Pocket Cost                                                   -0.38
# 2018__Uninsured                                                       0.27
#
#                                       Cancer Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                           0.80
# Cancer Death Rate per 100,000                                  1.00
# Poor Health                                                    0.67
# Poor Mental Health                                             0.63
# Trouble Paying Off Medical Bills                               0.60
# Out of Pocket Cost                                            -0.19
# 2018__Uninsured                                                0.08
#
#                                       Poor Health  Poor Mental Health  \
# Heart Disease Death Rate per 100,000         0.75                0.59
# Cancer Death Rate per 100,000                0.67                0.63
# Poor Health                                  1.00                0.69
# Poor Mental Health                           0.69                1.00
# Trouble Paying Off Medical Bills             0.42                0.42
# Out of Pocket Cost                          -0.68               -0.31
# 2018__Uninsured                              0.37                0.01
#
#                                       Trouble Paying Off Medical Bills  \
# Heart Disease Death Rate per 100,000                              0.55
# Cancer Death Rate per 100,000                                     0.60
# Poor Health                                                       0.42
# Poor Mental Health                                                0.42
# Trouble Paying Off Medical Bills                                  1.00
# Out of Pocket Cost                                                0.01
# 2018__Uninsured                                                   0.50
#
#                                       Out of Pocket Cost  2018__Uninsured
# Heart Disease Death Rate per 100,000               -0.38             0.27
# Cancer Death Rate per 100,000                      -0.19             0.08
# Poor Health                                        -0.68             0.37
# Poor Mental Health                                 -0.31             0.01
# Trouble Paying Off Medical Bills                    0.01             0.50
# Out of Pocket Cost                                  1.00            -0.36
# 2018__Uninsured                                    -0.36             1.00

# %%
corrs = overall_data.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', square=True)
plt.title('Correlation Heatmap Matrix')
# Out:
# Text(0.5, 1, 'Correlation Heatmap Matrix')

# %%
sm = pd.plotting.scatter_matrix(overall_data, figsize=(15, 15))
plt.xlabel('xlabel', fontsize=6)
plt.ylabel('ylabel', fontsize=6)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 6)
plt.tick_params(labelsize=6)
[s.xaxis.label.set_rotation(45) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(45) for s in sm.reshape(-1)]

plt.show()
