# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pingouin as pg
import seaborn as sns
plt.style.use('ggplot')

# %%
overall_data = pd.read_excel('~/github/gal/Analyzing-Medicare-Expansion/data2/All States Correlation Data.xlsx')

# %%
overall_data.describe()
# Out:
#        Heart Disease Death Rate  Cancer Death Rate  % Adults, Poor Health  \
# count                 50.000000          50.000000              50.000000
# mean                 164.296000         151.514000               0.179340
# std                   27.927566          14.349216               0.032466
# min                  119.000000         120.000000               0.134000
# 25%                  145.875000         141.975000               0.156000
# 50%                  158.900000         150.550000               0.173500
# 75%                  179.550000         160.675000               0.193750
# max                  228.500000         181.600000               0.263000
#
#        % Adults, Poor Mental Health  % Adults, No care due to cost  \
# count                     50.000000                      50.000000
# mean                       0.229724                       0.124328
# std                        0.023526                       0.026162
# min                        0.185900                       0.073460
# 25%                        0.214200                       0.105210
# 50%                        0.225100                       0.121645
# 75%                        0.245450                       0.147410
# max                        0.290900                       0.181990
#
#        % Adults, Trouble Paying Medical Bills  % Adults Uninsured
# count                               50.000000           50.000000
# mean                                 0.299040            0.081703
# std                                  0.065401            0.030327
# min                                  0.149000            0.027210
# 25%                                  0.263250            0.056302
# 50%                                  0.295500            0.078932
# 75%                                  0.341750            0.101761
# max                                  0.436000            0.176901

# %% [markdown]
# p-val is the p-value of the test. (p <.05 - columns are correlated) The general rule is that you can reject the hypothesis that the two variables are not correlated if the p-value is below 0.05.

# %%
pg.pairwise_corr(overall_data).sort_values(by=['p-unc'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#                                          X  \
# 19           % Adults, No care due to cost
# 0                 Heart Disease Death Rate
# 1                 Heart Disease Death Rate
# 11                   % Adults, Poor Health
# 12                   % Adults, Poor Health
# 6                        Cancer Death Rate
# 7                        Cancer Death Rate
# 9                        Cancer Death Rate
# 2                 Heart Disease Death Rate
# 18           % Adults, No care due to cost
# 4                 Heart Disease Death Rate
# 20  % Adults, Trouble Paying Medical Bills
# 3                 Heart Disease Death Rate
# 13                   % Adults, Poor Health
# 16            % Adults, Poor Mental Health
# 15            % Adults, Poor Mental Health
# 14                   % Adults, Poor Health
# 8                        Cancer Death Rate
# 5                 Heart Disease Death Rate
# 10                       Cancer Death Rate
# 17            % Adults, Poor Mental Health
#
#                                          Y   n         r         p-unc
# 19                      % Adults Uninsured  50  0.818576  3.837518e-13
# 0                        Cancer Death Rate  50  0.795987  4.878770e-12
# 1                    % Adults, Poor Health  50  0.746280  4.951457e-10
# 11            % Adults, Poor Mental Health  50  0.691548  2.688671e-08
# 12           % Adults, No care due to cost  50  0.672053  9.098341e-08
# 6                    % Adults, Poor Health  50  0.666475  1.268337e-07
# 7             % Adults, Poor Mental Health  50  0.634891  7.348093e-07
# 9   % Adults, Trouble Paying Medical Bills  50  0.599032  4.309674e-06
# 2             % Adults, Poor Mental Health  50  0.589381  6.692823e-06
# 18  % Adults, Trouble Paying Medical Bills  50  0.570099  1.547687e-05
# 4   % Adults, Trouble Paying Medical Bills  50  0.548881  3.670400e-05
# 20                      % Adults Uninsured  50  0.502979  1.970690e-04
# 3            % Adults, No care due to cost  50  0.493925  2.671100e-04
# 13  % Adults, Trouble Paying Medical Bills  50  0.421958  2.272092e-03
# 16  % Adults, Trouble Paying Medical Bills  50  0.420613  2.354743e-03
# 15           % Adults, No care due to cost  50  0.388889  5.252877e-03
# 14                      % Adults Uninsured  50  0.367915  8.572283e-03
# 8            % Adults, No care due to cost  50  0.340618  1.550003e-02
# 5                       % Adults Uninsured  50  0.272044  5.597840e-02
# 10                      % Adults Uninsured  50  0.081860  5.719738e-01
# 17                      % Adults Uninsured  50  0.008871  9.512434e-01

# %%
overall_data.corr().round(2)
# Out:
#                                         Heart Disease Death Rate  \
# Heart Disease Death Rate                                    1.00
# Cancer Death Rate                                           0.80
# % Adults, Poor Health                                       0.75
# % Adults, Poor Mental Health                                0.59
# % Adults, No care due to cost                               0.49
# % Adults, Trouble Paying Medical Bills                      0.55
# % Adults Uninsured                                          0.27
#
#                                         Cancer Death Rate  \
# Heart Disease Death Rate                             0.80
# Cancer Death Rate                                    1.00
# % Adults, Poor Health                                0.67
# % Adults, Poor Mental Health                         0.63
# % Adults, No care due to cost                        0.34
# % Adults, Trouble Paying Medical Bills               0.60
# % Adults Uninsured                                   0.08
#
#                                         % Adults, Poor Health  \
# Heart Disease Death Rate                                 0.75
# Cancer Death Rate                                        0.67
# % Adults, Poor Health                                    1.00
# % Adults, Poor Mental Health                             0.69
# % Adults, No care due to cost                            0.67
# % Adults, Trouble Paying Medical Bills                   0.42
# % Adults Uninsured                                       0.37
#
#                                         % Adults, Poor Mental Health  \
# Heart Disease Death Rate                                        0.59
# Cancer Death Rate                                               0.63
# % Adults, Poor Health                                           0.69
# % Adults, Poor Mental Health                                    1.00
# % Adults, No care due to cost                                   0.39
# % Adults, Trouble Paying Medical Bills                          0.42
# % Adults Uninsured                                              0.01
#
#                                         % Adults, No care due to cost  \
# Heart Disease Death Rate                                         0.49
# Cancer Death Rate                                                0.34
# % Adults, Poor Health                                            0.67
# % Adults, Poor Mental Health                                     0.39
# % Adults, No care due to cost                                    1.00
# % Adults, Trouble Paying Medical Bills                           0.57
# % Adults Uninsured                                               0.82
#
#                                         % Adults, Trouble Paying Medical Bills  \
# Heart Disease Death Rate                                                  0.55
# Cancer Death Rate                                                         0.60
# % Adults, Poor Health                                                     0.42
# % Adults, Poor Mental Health                                              0.42
# % Adults, No care due to cost                                             0.57
# % Adults, Trouble Paying Medical Bills                                    1.00
# % Adults Uninsured                                                        0.50
#
#                                         % Adults Uninsured
# Heart Disease Death Rate                              0.27
# Cancer Death Rate                                     0.08
# % Adults, Poor Health                                 0.37
# % Adults, Poor Mental Health                          0.01
# % Adults, No care due to cost                         0.82
# % Adults, Trouble Paying Medical Bills                0.50
# % Adults Uninsured                                    1.00

# %%
corrs = overall_data.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', square=True, annot = True)
plt.title('Correlation Heatmap Matrix')

plt.title('Correlation Heatmap For All States')
plt.savefig('Heatmap_all_states.png')

# %%
import seaborn as sns
sns.set(style="ticks")

g = sns.pairplot(overall_data, kind = 'reg', corner=True)
g.fig.suptitle("Scatter Matrix of Data for All States", y=1)
plt.savefig('Scatter_Matrix_all_states.png')
