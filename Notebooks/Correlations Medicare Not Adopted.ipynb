# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pingouin as pg
import seaborn as sns
plt.style.use('ggplot')

# %%
overall_data = pd.read_excel('Desktop/Health Data Not Adopted.xlsx')

# %%
overall_data.describe()
# Out:
#        Heart Disease Death Rate per 100,000  Cancer Death Rate per 100,000  \
# count                             19.000000                      19.000000
# mean                             170.952632                     154.478947
# std                               28.427908                      14.264937
# min                              143.100000                     120.000000
# 25%                              150.300000                     147.250000
# 50%                              157.900000                     152.400000
# 75%                              182.100000                     163.700000
# max                              228.500000                     179.700000
#
#        Poor Health  Poor Mental Health  No care due to cost  \
# count    19.000000           19.000000            19.000000
# mean      0.185000            0.228337             0.142204
# std       0.029107            0.021732             0.023764
# min       0.145000            0.185900             0.099250
# 25%       0.159000            0.211900             0.125750
# 50%       0.189000            0.226400             0.149040
# 75%       0.206000            0.245000             0.159940
# max       0.233000            0.263400             0.181990
#
#        Trouble Paying Off Medical Bills  2018__Uninsured
# count                         19.000000        19.000000
# mean                           0.344158         0.105744
# std                            0.044347         0.026905
# min                            0.266000         0.055387
# 25%                            0.324500         0.088564
# 50%                            0.342000         0.101776
# 75%                            0.361000         0.117004
# max                            0.436000         0.176901

# %% [markdown]
# p-val is the p-value of the test. (p <.05 - columns are correlated) The general rule is that you can reject the hypothesis that the two variables are not correlated if the p-value is below 0.05.

# %%
pg.pairwise_corr(overall_data).sort_values(by=['p-unc'])[['X', 'Y', 'n', 'r', 'p-unc']]
# Out:
#                                        X                                 Y  \
# 1   Heart Disease Death Rate per 100,000                       Poor Health
# 0   Heart Disease Death Rate per 100,000     Cancer Death Rate per 100,000
# 19                   No care due to cost                   2018__Uninsured
# 6          Cancer Death Rate per 100,000                       Poor Health
# 12                           Poor Health               No care due to cost
# 2   Heart Disease Death Rate per 100,000                Poor Mental Health
# 11                           Poor Health                Poor Mental Health
# 7          Cancer Death Rate per 100,000                Poor Mental Health
# 3   Heart Disease Death Rate per 100,000               No care due to cost
# 14                           Poor Health                   2018__Uninsured
# 4   Heart Disease Death Rate per 100,000  Trouble Paying Off Medical Bills
# 15                    Poor Mental Health               No care due to cost
# 9          Cancer Death Rate per 100,000  Trouble Paying Off Medical Bills
# 5   Heart Disease Death Rate per 100,000                   2018__Uninsured
# 8          Cancer Death Rate per 100,000               No care due to cost
# 18                   No care due to cost  Trouble Paying Off Medical Bills
# 16                    Poor Mental Health  Trouble Paying Off Medical Bills
# 20      Trouble Paying Off Medical Bills                   2018__Uninsured
# 13                           Poor Health  Trouble Paying Off Medical Bills
# 17                    Poor Mental Health                   2018__Uninsured
# 10         Cancer Death Rate per 100,000                   2018__Uninsured
#
#      n         r     p-unc
# 1   19  0.798064  0.000042
# 0   19  0.797771  0.000043
# 19  19  0.784920  0.000069
# 6   19  0.740173  0.000291
# 12  19  0.713842  0.000598
# 2   19  0.607219  0.005830
# 11  19  0.549743  0.014754
# 7   19  0.524244  0.021215
# 3   19  0.506456  0.026916
# 14  19  0.448766  0.053946
# 4   19  0.361828  0.127955
# 15  19  0.329310  0.168592
# 9   19  0.321757  0.179161
# 5   19  0.320880  0.180416
# 8   19  0.288350  0.231230
# 18  19  0.228018  0.347790
# 16  19  0.214479  0.377912
# 20  19  0.203962  0.402282
# 13  19  0.165872  0.497355
# 17  19 -0.073368  0.765326
# 10  19  0.058270  0.812694

# %%
overall_data.corr().round(2)
# Out:
#                                       Heart Disease Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                                  1.00
# Cancer Death Rate per 100,000                                         0.80
# Poor Health                                                           0.80
# Poor Mental Health                                                    0.61
# No care due to cost                                                   0.51
# Trouble Paying Off Medical Bills                                      0.36
# 2018__Uninsured                                                       0.32
#
#                                       Cancer Death Rate per 100,000  \
# Heart Disease Death Rate per 100,000                           0.80
# Cancer Death Rate per 100,000                                  1.00
# Poor Health                                                    0.74
# Poor Mental Health                                             0.52
# No care due to cost                                            0.29
# Trouble Paying Off Medical Bills                               0.32
# 2018__Uninsured                                                0.06
#
#                                       Poor Health  Poor Mental Health  \
# Heart Disease Death Rate per 100,000         0.80                0.61
# Cancer Death Rate per 100,000                0.74                0.52
# Poor Health                                  1.00                0.55
# Poor Mental Health                           0.55                1.00
# No care due to cost                          0.71                0.33
# Trouble Paying Off Medical Bills             0.17                0.21
# 2018__Uninsured                              0.45               -0.07
#
#                                       No care due to cost  \
# Heart Disease Death Rate per 100,000                 0.51
# Cancer Death Rate per 100,000                        0.29
# Poor Health                                          0.71
# Poor Mental Health                                   0.33
# No care due to cost                                  1.00
# Trouble Paying Off Medical Bills                     0.23
# 2018__Uninsured                                      0.78
#
#                                       Trouble Paying Off Medical Bills  \
# Heart Disease Death Rate per 100,000                              0.36
# Cancer Death Rate per 100,000                                     0.32
# Poor Health                                                       0.17
# Poor Mental Health                                                0.21
# No care due to cost                                               0.23
# Trouble Paying Off Medical Bills                                  1.00
# 2018__Uninsured                                                   0.20
#
#                                       2018__Uninsured
# Heart Disease Death Rate per 100,000             0.32
# Cancer Death Rate per 100,000                    0.06
# Poor Health                                      0.45
# Poor Mental Health                              -0.07
# No care due to cost                              0.78
# Trouble Paying Off Medical Bills                 0.20
# 2018__Uninsured                                  1.00

# %%
corrs = overall_data.corr()
mask = np.zeros_like(corrs)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', square=True)
plt.title('Correlation Heatmap Matrix')
# Out:
# Text(0.5, 1, 'Correlation Heatmap Matrix')

# %%
sm = pd.plotting.scatter_matrix(overall_data, figsize=(15, 15))
plt.xlabel('xlabel', fontsize=6)
plt.ylabel('ylabel', fontsize=6)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 6)
plt.tick_params(labelsize=6)
[s.xaxis.label.set_rotation(45) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(45) for s in sm.reshape(-1)]

plt.show()
